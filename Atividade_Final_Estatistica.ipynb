# %% [markdown]
# <a href="https://colab.research.google.com/github/Riva2025/ESTATISTICA/blob/main/Atividade_Final_Estatistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

afl_finalists = pd.read_csv('https://raw.githubusercontent.com/ethanweed/pythonbook/main/Data/afl_finalists.csv')
afl_margins = pd.read_csv('https://raw.githubusercontent.com/ethanweed/pythonbook/main/Data/afl_margins.csv')

# %%
print(afl_margins)
# Out:
#      afl.margins
# 0             56
# 1             31
# 2             56
# 3              8
# 4             32
# ..           ...
# 171           28
# 172           38
# 173           29
# 174           10
# 175           10
#
# [176 rows x 1 columns]

# %%
margins = afl_margins['afl.margins']

sum(margins)
# Out:
# 6213

# %%
margins[0:5]
# Out:
# 0    56
# 1    31
# 2    56
# 3     8
# 4    32
# Name: afl.margins, dtype: int64

# %%
sum(margins[0:5])/5
# Out:
# 36.6

# %%
margins[0:5].mean()
# Out:
# np.float64(36.6)

# %%
a = list(margins)
a
# Out:
# [56,
#  31,
#  56,
#  8,
#  32,
#  14,
#  36,
#  56,
#  19,
#  1,
#  3,
#  104,
#  43,
#  44,
#  72,
#  9,
#  28,
#  25,
#  27,
#  55,
#  20,
#  16,
#  16,
#  7,
#  23,
#  40,
#  48,
#  64,
#  22,
#  55,
#  95,
#  15,
#  49,
#  52,
#  50,
#  10,
#  65,
#  12,
#  39,
#  36,
#  3,
#  26,
#  23,
#  20,
#  43,
#  108,
#  53,
#  38,
#  4,
#  8,
#  3,
#  13,
#  66,
#  67,
#  50,
#  61,
#  36,
#  38,
#  29,
#  9,
#  81,
#  3,
#  26,
#  12,
#  36,
#  37,
#  70,
#  1,
#  35,
#  12,
#  50,
#  35,
#  9,
#  54,
#  47,
#  8,
#  47,
#  2,
#  29,
#  61,
#  38,
#  41,
#  23,
#  24,
#  1,
#  9,
#  11,
#  10,
#  29,
#  47,
#  71,
#  38,
#  49,
#  65,
#  18,
#  0,
#  16,
#  9,
#  19,
#  36,
#  60,
#  24,
#  25,
#  44,
#  55,
#  3,
#  57,
#  83,
#  84,
#  35,
#  4,
#  35,
#  26,
#  22,
#  2,
#  14,
#  19,
#  30,
#  19,
#  68,
#  11,
#  75,
#  48,
#  32,
#  36,
#  39,
#  50,
#  11,
#  0,
#  63,
#  82,
#  26,
#  3,
#  82,
#  73,
#  19,
#  33,
#  48,
#  8,
#  10,
#  53,
#  20,
#  71,
#  75,
#  76,
#  54,
#  44,
#  5,
#  22,
#  94,
#  29,
#  8,
#  98,
#  9,
#  89,
#  1,
#  101,
#  7,
#  21,
#  52,
#  42,
#  21,
#  116,
#  3,
#  44,
#  29,
#  27,
#  16,
#  6,
#  44,
#  3,
#  28,
#  38,
#  29,
#  10,
#  10]

# %%
import statistics
statistics.mean(margins)
# Out:
# 35.30113636363637

# %%
# Media
statistics.mean(margins[0:5])
# Out:
# 36.6

# %%
# Mediana
#ordenar a coluna
sorted_margins = afl_margins.sort_values(by = 'afl.margins')

# %%
sorted_margins
# Out:
#      afl.margins
# 95             0
# 128            0
# 67             1
# 9              1
# 155            1
# ..           ...
# 152           98
# 156          101
# 11           104
# 45           108
# 162          116
#
# [176 rows x 1 columns]

# %%
sorted_margins[84:92]
# Out:
#      afl.margins
# 58            29
# 150           29
# 165           29
# 117           30
# 1             31
# 4             32
# 123           32
# 136           33
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['afl.margins'].plot(kind='hist', bins=20, title='afl.margins')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['afl.margins']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'afl.margins'}, axis=1)
#               .sort_values('afl.margins', ascending=True))
#   xs = counted['afl.margins']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_2.sort_values('afl.margins', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('afl.margins')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['afl.margins'].plot(kind='line', figsize=(8, 4), title='afl.margins')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_1['afl.margins'].plot(kind='hist', bins=20, title='afl.margins')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_1['afl.margins'].plot(kind='hist', bins=20, title='afl.margins')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
margins.median()
# Out:
# 30.5

# %%
#Moda
afl_finalists.head(n=25)
# Out:
#    afl.finalists
# 0       Hawthorn
# 1      Melbourne
# 2        Carlton
# 3      Melbourne
# 4       Hawthorn
# 5        Carlton
# 6      Melbourne
# 7        Carlton
# 8       Hawthorn
# 9      Melbourne
# 10     Melbourne
# 11      Hawthorn
# 12     Melbourne
# 13      Essendon
# 14      Hawthorn
# 15       Geelong
# 16       Geelong
# 17      Hawthorn
# 18   Collingwood
# 19     Melbourne
# 20   Collingwood
# 21    West Coast
# 22   Collingwood
# 23      Essendon
# 24   Collingwood
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('afl.finalists').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
finalists = afl_finalists['afl.finalists']
finalists.value_counts()
# Out:
# afl.finalists
# Geelong             39
# West Coast          38
# Essendon            32
# Melbourne           28
# Collingwood         28
# North Melbourne     28
# Hawthorn            27
# Carlton             26
# Sydney              26
# Adelaide            26
# Brisbane            25
# St Kilda            24
# Western Bulldogs    24
# Port Adelaide       17
# Richmond             6
# Fremantle            6
# Name: count, dtype: int64

# %%
statistics.mode(finalists)
# Out:
# 'Geelong'

# %%
freq = finalists.value_counts()
freq.max()
# Out:
# 39

# %%
statistics.mode(margins)
# Out:
# 3

# %%
freq = margins.value_counts()
freq.max()
# Out:
# 8

# %%
#Range
maximo = margins.max()
minimo = margins.min()
maximo
# Out:
# 116

# %%
minimo
# Out:
# 0

# %%
# Variancia
var = statistics.variance(afl_margins['afl.margins'])

var
# Out:
# 679.834512987013

# %%
#Desvio Padrao
statistics.stdev(margins)
# Out:
# 26.073636359108274
